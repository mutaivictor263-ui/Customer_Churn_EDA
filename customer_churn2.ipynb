# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('customer_churn_dataset.csv')

df
# Out:
#        customer_id  tenure  monthly_charges  total_charges        contract  \
# 0                1      52            54.20        2818.40  Month-to-month
# 1                2      15            35.28         529.20  Month-to-month
# 2                3      72            78.24        5633.28  Month-to-month
# 3                4      61            80.24        4894.64        One year
# 4                5      21            39.38         826.98  Month-to-month
# ...            ...     ...              ...            ...             ...
# 19995        19996      36            69.51        2502.36        Two year
# 19996        19997      10            59.88         598.80  Month-to-month
# 19997        19998       6            42.96         257.76  Month-to-month
# 19998        19999       7           102.85         719.95  Month-to-month
# 19999        20000      31            44.84        1390.04        Two year
#
# ...

# %%
print(df.to_string())
# Out:
#        customer_id  tenure  monthly_charges  total_charges        contract payment_method internet_service tech_support online_security  support_calls churn
# 0                1      52            54.20        2818.40  Month-to-month         Credit              DSL           No             Yes              1    No
# 1                2      15            35.28         529.20  Month-to-month          Debit              DSL           No              No              2    No
# 2                3      72            78.24        5633.28  Month-to-month          Debit              DSL           No              No              0    No
# 3                4      61            80.24        4894.64        One year           Cash            Fiber          Yes             Yes              0    No
# 4                5      21            39.38         826.98  Month-to-month            UPI            Fiber           No              No              4   Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       20000 non-null  int64
#  1   tenure            20000 non-null  int64
#  2   monthly_charges   20000 non-null  float64
#  3   total_charges     20000 non-null  float64
#  4   contract          20000 non-null  object
#  5   payment_method    20000 non-null  object
#  6   internet_service  17987 non-null  object
#  7   tech_support      20000 non-null  object
#  8   online_security   20000 non-null  object
#  9   support_calls     20000 non-null  int64
#  10  churn             20000 non-null  object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 1.7+ MB

# %%
df.isnull().sum()
# Out:
# customer_id            0
# tenure                 0
# monthly_charges        0
# total_charges          0
# contract               0
# payment_method         0
# internet_service    2013
# tech_support           0
# online_security        0
# support_calls          0
# churn                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# customer_id         0
# tenure              0
# monthly_charges     0
# total_charges       0
# contract            0
# payment_method      0
# internet_service    0
# tech_support        0
# online_security     0
# support_calls       0
# churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['customer_id', 'tenure', 'monthly_charges', 'total_charges', 'contract',
#        'payment_method', 'internet_service', 'tech_support', 'online_security',
#        'support_calls', 'churn'],
#       dtype='object')

# %%
df.pivot_table(index='internet_service', values='monthly_charges', aggfunc='mean')
# Out:
#                   monthly_charges
# internet_service
# DSL                     70.012389
# Fiber                   70.150324

# %%
sns.countplot(x='churn', data=df)
# Out:
# <Axes: xlabel='churn', ylabel='count'>

# %%
sns.boxplot(x='churn', y="tenure", data=df)
# Out:
# <Axes: xlabel='churn', ylabel='tenure'>

# %%
sns.boxplot(x='churn', y='monthly_charges', data=df)
# Out:
# <Axes: xlabel='churn', ylabel='monthly_charges'>

# %%
sns.boxplot(x='churn', y='total_charges', data=df)
# Out:
# <Axes: xlabel='churn', ylabel='total_charges'>

# %%
sns.countplot(x='internet_service', hue='churn', data=df)
# Out:
# <Axes: xlabel='internet_service', ylabel='count'>

# %%
sns.countplot(x='contract', hue='churn', data=df)
# Out:
# <Axes: xlabel='contract', ylabel='count'>

# %%
sns.countplot(x='payment_method', hue='churn', data=df)
# Out:
# <Axes: xlabel='payment_method', ylabel='count'>

# %%
sns.countplot(x='tech_support', hue='churn', data=df)
# Out:
# <Axes: xlabel='tech_support', ylabel='count'>

# %%
sns.countplot(x='online_security', hue='churn', data=df)
# Out:
# <Axes: xlabel='online_security', ylabel='count'>

# %%
df.corr(numeric_only=True)
# Out:
#                  customer_id    tenure  monthly_charges  total_charges  \
# customer_id         1.000000  0.005671        -0.005978       0.003726
# tenure              0.005671  1.000000        -0.012597       0.766987
# monthly_charges    -0.005978 -0.012597         1.000000       0.547468
# total_charges       0.003726  0.766987         0.547468       1.000000
# support_calls       0.013719 -0.005054        -0.001985      -0.006839
#
#                  support_calls
# customer_id           0.013719
# tenure               -0.005054
# monthly_charges      -0.001985
# total_charges        -0.006839
# support_calls         1.000000

# %%
df.columns
# Out:
# Index(['customer_id', 'tenure', 'monthly_charges', 'total_charges', 'contract',
#        'payment_method', 'internet_service', 'tech_support', 'online_security',
#        'support_calls', 'churn'],
#       dtype='object')
